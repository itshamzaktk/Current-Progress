# %% [markdown]
# >-  # Pandas Library:

# %%
import pandas as pd
import numpy as np

# %%
Series1=pd.Series([1,2,3])

# %%
Series1
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
Series2=pd.Series([4,5,6],index=['a','b','c'])
Series2
# Out:
# a    4
# b    5
# c    6
# dtype: int64

# %%
Series3=pd.Series([4,5,6])
Series3
# Out:
# 0    4
# 1    5
# 2    6
# dtype: int64

# %%
DF=pd.DataFrame({ 'Col1' : Series1 , 'Col2' : Series3})
DF
# Out:
#    Col1  Col2
# 0     1     4
# 1     2     5
# 2     3     6

# %%
Data={
    'A':[1,2,3,4,5],
    'B':['A','B','C','D','E']
}
DF2=pd.DataFrame(Data)
DF2
# Out:
#    A  B
# 0  1  A
# 1  2  B
# 2  3  C
# 3  4  D
# 4  5  E

# %%
DF3=pd.read_excel('car-sales.xlsx')
DF3
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
DF3.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500

# %%
DF3.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
DF3.describe()
# Out:
#        Odometer (KM)      Doors         Price
# count      10.000000  10.000000     10.000000
# mean    78601.400000   4.000000   7645.000000
# std     61983.471735   0.471405   5379.407753
# min     11179.000000   3.000000   3500.000000
# 25%     35836.250000   4.000000   4625.000000
# 50%     57369.000000   4.000000   6625.000000
# 75%     96384.500000   4.000000   7375.000000
# max    213095.000000   5.000000  22000.000000

# %%
DF3.describe(include='all')
# Out:
#           Make Colour  Odometer (KM)      Doors         Price
# count       10     10      10.000000  10.000000     10.000000
# unique       4      5            NaN        NaN           NaN
# top     Toyota  White            NaN        NaN           NaN
# freq         4      4            NaN        NaN           NaN
# mean       NaN    NaN   78601.400000   4.000000   7645.000000
# std        NaN    NaN   61983.471735   0.471405   5379.407753
# min        NaN    NaN   11179.000000   3.000000   3500.000000
# 25%        NaN    NaN   35836.250000   4.000000   4625.000000
# 50%        NaN    NaN   57369.000000   4.000000   6625.000000
# 75%        NaN    NaN   96384.500000   4.000000   7375.000000
# max        NaN    NaN  213095.000000   5.000000  22000.000000

# %%
DF3.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
DF3.values
# Out:
# array([['Toyota', 'White', 150043, 4, 4000],
#        ['Honda', 'Red', 87899, 4, 5000],
#        ['Toyota', 'Blue', 32549, 3, 7000],
#        ['BMW', 'Black', 11179, 5, 22000],
#        ['Nissan', 'White', 213095, 4, 3500],
#        ['Toyota', 'Green', 99213, 4, 4500],
#        ['Honda', 'Blue', 45698, 4, 7500],
#        ['Honda', 'Blue', 54738, 4, 7000],
#        ['Toyota', 'White', 60000, 4, 6250],
#        ['Nissan', 'White', 31600, 4, 9700]], dtype=object)

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Col1    3 non-null      int64
#  1   Col2    3 non-null      int64
# dtypes: int64(2)
# memory usage: 176.0 bytes

# %%
DF3.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %%
DF3.count()
# Out:
# Make             10
# Colour           10
# Odometer (KM)    10
# Doors            10
# Price            10
# dtype: int64

# %%
DF3.value_counts()
# Out:
# Make    Colour  Odometer (KM)  Doors  Price
# BMW     Black   11179          5      22000    1
# Honda   Blue    45698          4      7500     1
#                 54738          4      7000     1
#         Red     87899          4      5000     1
# Nissan  White   31600          4      9700     1
#                 213095         4      3500     1
# Toyota  Blue    32549          3      7000     1
#         Green   99213          4      4500     1
#         White   60000          4      6250     1
#                 150043         4      4000     1
# Name: count, dtype: int64

# %%
DF4=pd.read_excel('carMissingData.xlsx')
DF4
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White       150043.0      4   4000.0
# 1   Honda    NaN        87899.0      4   5000.0
# 2  Toyota   Blue            NaN      3   7000.0
# 3     BMW  Black        11179.0      5  22000.0
# 4  Nissan  White       213095.0      4   3500.0
# 5  Toyota  Green        99213.0      4   4500.0
# 6   Honda    NaN            NaN      4   7500.0
# 7   Honda   Blue        54738.0      4      NaN
# 8  Toyota  White        60000.0      4   6250.0
# 9  Nissan  White        31600.0      4   9700.0

# %%
DF4.value_counts()
# Out:
# Make    Colour  Odometer (KM)  Doors  Price
# BMW     Black   11179.0        5      22000.0    1
# Nissan  White   31600.0        4      9700.0     1
#                 213095.0       4      3500.0     1
# Toyota  Green   99213.0        4      4500.0     1
#         White   60000.0        4      6250.0     1
#                 150043.0       4      4000.0     1
# Name: count, dtype: int64

# %%
DF4.value_counts(dropna=False,normalize=True)
# Out:
# Make    Colour  Odometer (KM)  Doors  Price
# BMW     Black   11179.0        5      22000.0    0.1
# Honda   Blue    54738.0        4      NaN        0.1
#         NaN     87899.0        4      5000.0     0.1
#                 NaN            4      7500.0     0.1
# Nissan  White   31600.0        4      9700.0     0.1
#                 213095.0       4      3500.0     0.1
# Toyota  Blue    NaN            3      7000.0     0.1
#         Green   99213.0        4      4500.0     0.1
#         White   60000.0        4      6250.0     0.1
#                 150043.0       4      4000.0     0.1
# Name: proportion, dtype: float64

# %%
DF3.memory_usage()
# Out:
# Index            128
# Make              80
# Colour            80
# Odometer (KM)     80
# Doors             80
# Price             80
# dtype: int64

# %%
DF4.value_counts()
# Out:
# Make    Colour  Odometer (KM)  Doors  Price
# BMW     Black   11179.0        5      22000.0    1
# Nissan  White   31600.0        4      9700.0     1
#                 213095.0       4      3500.0     1
# Toyota  Green   99213.0        4      4500.0     1
#         White   60000.0        4      6250.0     1
#                 150043.0       4      4000.0     1
# Name: count, dtype: int64

# %%
DF4.shape
# Out:
# (10, 5)

# %%
DF4.size
# Out:
# 50

# %%
DF4.count()
# Out:
# Make             10
# Colour            8
# Odometer (KM)     8
# Doors            10
# Price             9
# dtype: int64

# %%
DF3.count()
# Out:
# Make             10
# Colour           10
# Odometer (KM)    10
# Doors            10
# Price            10
# dtype: int64

# %%
DF3.nunique()
# Out:
# Make              4
# Colour            5
# Odometer (KM)    10
# Doors             3
# Price             9
# dtype: int64

# %%
DF3
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
DF3.to_csv('NewCarCSV.csv',index=False)

# %%
DF5=pd.read_csv('NewCarCSV.csv')
DF5
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
DF5.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
DF5.sample(5)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 5  Toyota  Green          99213      4   4500
# 7   Honda   Blue          54738      4   7000
# 6   Honda   Blue          45698      4   7500
# 2  Toyota   Blue          32549      3   7000
# 1   Honda    Red          87899      4   5000

# %%
DF5.loc[0]
# Out:
# Make             Toyota
# Colour            White
# Odometer (KM)    150043
# Doors                 4
# Price              4000
# Name: 0, dtype: object

# %%
DF5.loc[0,'Make']
# Out:
# 'Toyota'

# %%
DF5.iloc[:,0]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
DF5.iloc[0]
# Out:
# Make             Toyota
# Colour            White
# Odometer (KM)    150043
# Doors                 4
# Price              4000
# Name: 0, dtype: object

# %%
DF5.iloc[0,0]
# Out:
# 'Toyota'

# %%
DF5.columns.get_loc('Odometer (KM)')
# Out:
# 2

# %%
DF5.duplicated(keep='first')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
DF5.duplicated(keep='last')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
DF5.duplicated(subset=['Make'],keep='first')
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# dtype: bool

# %%
DF5.duplicated(subset=['Make'],keep='last')
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
DF5.duplicated().any().sum()
# Out:
# 0

# %%
DF5['Make'].duplicated().any()
# Out:
# True

# %%
DF5['Make'].duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: Make, dtype: bool

# %%
DF5['Make'].duplicated().sum()
# Out:
# 6

# %%
DF5.duplicated(keep=False)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
DF5.duplicated(keep=False).any()
# Out:
# False

# %%
DF5.sample(frac=0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 6   Honda   Blue          45698      4   7500
# 5  Toyota  Green          99213      4   4500
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 7   Honda   Blue          54738      4   7000

# %%
DF5.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700
# 2  Toyota   Blue          32549      3   7000
# 5  Toyota  Green          99213      4   4500
# 4  Nissan  White         213095      4   3500
# 7   Honda   Blue          54738      4   7000
# 1   Honda    Red          87899      4   5000
# 3     BMW  Black          11179      5  22000
# 6   Honda   Blue          45698      4   7500

# %%
DF5.max()
# Out:
# Make             Toyota
# Colour            White
# Odometer (KM)    213095
# Doors                 5
# Price             22000
# dtype: object

# %%
DF5.min()
# Out:
# Make               BMW
# Colour           Black
# Odometer (KM)    11179
# Doors                3
# Price             3500
# dtype: object

# %%
DF5.idxmax()
# Out:
# Make             0
# Colour           0
# Odometer (KM)    4
# Doors            3
# Price            3
# dtype: int64

# %%
Series3
# Out:
# 0    4
# 1    5
# 2    6
# dtype: int64

# %%
Series3.idxmax()
# Out:
# 2

# %%
Series3.max()
# Out:
# 6

# %%
DF5['Make'].drop_duplicates()
# Out:
# 0    Toyota
# 1     Honda
# 3       BMW
# 4    Nissan
# Name: Make, dtype: object

# %%
DF5.drop_duplicates().any()
# Out:
# Make             True
# Colour           True
# Odometer (KM)    True
# Doors            True
# Price            True
# dtype: bool

# %%
DF5
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
pd.crosstab(DF5['Make'],DF5['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
DF
# Out:
#    Col1  Col2
# 0     1     4
# 1     2     5
# 2     3     6

# %%
DF['Col3'] = [7,8,9]

# %%
DF
# Out:
#    Col1  Col2  Col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
DF4
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White       150043.0      4   4000.0
# 1   Honda    NaN        87899.0      4   5000.0
# 2  Toyota   Blue            NaN      3   7000.0
# 3     BMW  Black        11179.0      5  22000.0
# 4  Nissan  White       213095.0      4   3500.0
# 5  Toyota  Green        99213.0      4   4500.0
# 6   Honda    NaN            NaN      4   7500.0
# 7   Honda   Blue        54738.0      4      NaN
# 8  Toyota  White        60000.0      4   6250.0
# 9  Nissan  White        31600.0      4   9700.0

# %%
DF4['Colour'].str.contains('White',na='NaN')
# Out:
# 0     True
# 1      NaN
# 2    False
# 3    False
# 4     True
# 5    False
# 6      NaN
# 7    False
# 8     True
# 9     True
# Name: Colour, dtype: object

# %%
DF4['Colour'].str.contains('White')
# Out:
# 0     True
# 1      NaN
# 2    False
# 3    False
# 4     True
# 5    False
# 6      NaN
# 7    False
# 8     True
# 9     True
# Name: Colour, dtype: object

# %%
Unique_Make=DF4['Make'].dropna().unique()

# %%
Unique_Make
# Out:
# array(['Toyota', 'Honda', 'BMW', 'Nissan'], dtype=object)

# %%
DF4
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White       150043.0      4   4000.0
# 1   Honda    NaN        87899.0      4   5000.0
# 2  Toyota   Blue            NaN      3   7000.0
# 3     BMW  Black        11179.0      5  22000.0
# 4  Nissan  White       213095.0      4   3500.0
# 5  Toyota  Green        99213.0      4   4500.0
# 6   Honda    NaN            NaN      4   7500.0
# 7   Honda   Blue        54738.0      4      NaN
# 8  Toyota  White        60000.0      4   6250.0
# 9  Nissan  White        31600.0      4   9700.0

# %%
DF4.dropna(subset=['Colour','Odometer (KM)','Price'],axis=0,how='any')
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White       150043.0      4   4000.0
# 3     BMW  Black        11179.0      5  22000.0
# 4  Nissan  White       213095.0      4   3500.0
# 5  Toyota  Green        99213.0      4   4500.0
# 8  Toyota  White        60000.0      4   6250.0
# 9  Nissan  White        31600.0      4   9700.0

# %%
DF4['Odometer (KM)'].fillna(value=DF4['Odometer (KM)'].mean(),axis=0,limit=None,inplace=True)

# %%
DF4
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White     150043.000      4   4000.0
# 1   Honda    NaN      87899.000      4   5000.0
# 2  Toyota   Blue      88470.875      3   7000.0
# 3     BMW  Black      11179.000      5  22000.0
# 4  Nissan  White     213095.000      4   3500.0
# 5  Toyota  Green      99213.000      4   4500.0
# 6   Honda    NaN      88470.875      4   7500.0
# 7   Honda   Blue      54738.000      4      NaN
# 8  Toyota  White      60000.000      4   6250.0
# 9  Nissan  White      31600.000      4   9700.0

# %%
DF4['Price'].fillna(method='ffill',inplace=True)
# Out:
# C:\Users\Waleed Abdullah\AppData\Local\Temp\ipykernel_37420\2101046110.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   DF4['Price'].fillna(method='bfill',inplace=True)
# C:\Users\Waleed Abdullah\AppData\Local\Temp\ipykernel_37420\2101046110.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   DF4['Price'].fillna(method='bfill',inplace=True)

# %%
DF4
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White     150043.000      4   4000.0
# 1   Honda    NaN      87899.000      4   5000.0
# 2  Toyota   Blue      88470.875      3   7000.0
# 3     BMW  Black      11179.000      5  22000.0
# 4  Nissan  White     213095.000      4   3500.0
# 5  Toyota  Green      99213.000      4   4500.0
# 6   Honda    NaN      88470.875      4   7500.0
# 7   Honda   Blue      54738.000      4   7500.0
# 8  Toyota  White      60000.000      4   6250.0
# 9  Nissan  White      31600.000      4   9700.0

# %%
Numerical_Cols=DF5.select_dtypes(include=['int64','float64']).columns
Categorical_Cols=DF5.select_dtypes(include=['object']).columns

# %%
Numerical_Cols
# Out:
# Index(['Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
Categorical_Cols
# Out:
# Index(['Make', 'Colour'], dtype='object')

# %%
Correlation_Matrix=DF5[Numerical_Cols].corr()

# %%
Correlation_Matrix
# Out:
#                Odometer (KM)     Doors     Price
# Odometer (KM)       1.000000 -0.081263 -0.631781
# Doors              -0.081263  1.000000  0.657235
# Price              -0.631781  0.657235  1.000000

# %%
Absolute_Vals=Correlation_Matrix.abs()

# %%
Absolute_Vals
# Out:
#                Odometer (KM)     Doors     Price
# Odometer (KM)       1.000000  0.081263  0.631781
# Doors               0.081263  1.000000  0.657235
# Price               0.631781  0.657235  1.000000

# %%
np.fill_diagonal(Absolute_Vals.values,0)

# %%
Absolute_Vals
# Out:
#                Odometer (KM)     Doors     Price
# Odometer (KM)       0.000000  0.081263  0.631781
# Doors               0.081263  0.000000  0.657235
# Price               0.631781  0.657235  0.000000

# %%
Absolute_Vals.idxmax()
# Out:
# Odometer (KM)    Price
# Doors            Price
# Price            Doors
# dtype: object

# %%
Absolute_Vals.max()
# Out:
# Odometer (KM)    0.631781
# Doors            0.657235
# Price            0.657235
# dtype: float64

# %%
Absolute_Vals.unstack().idxmax()
# Out:
# ('Doors', 'Price')

# %%
Absolute_Vals.unstack().max()
# Out:
# 0.6572347864263308
